# %%
import re
import pandas as pd
import glob

# %%
file = "S:/1683428/Learning/TCS Training/Python Training/smaple_info.txt"

# %%
pattern = re.compile('finished enrichment')
myvar = pd.DataFrame(columns =['First_col', 'Second_Col', 'Third_col', 'Forth_col'])

for line in open(file,'r'):
    lines = pattern.search(line)
    string_to_add = line[lines.span()[0]:].split('; ')
    myvar.loc[len(myvar.index)] = [string_to_add[0], string_to_add[1], string_to_add[2], string_to_add[3]]
print(myvar)
# Out:
#              First_col Second_Col Third_col Forth_col
# 0  finished enrichment        111       aaa       ppp
# 1  finished enrichment        222       bbb       qqq
# 2  finished enrichment        333       ccc       rrr
# 3  finished enrichment        444       ddd       sss
# 4  finished enrichment        555       eee       ttt

# %%
#Trying some additional activity
#Precedent of AND and OR operators
#AND operator has higher precendent 
#So even if you haven't give any () then
#AND condition will execute first and then or condition

x = True
y = False

print(x or x and y)
# Out:
# True

# %%
print(y or x and x or y)
# Out:
# True

# %%
#Trying glob in python for file patter matching
#printing details of folder and files only under ../TryGlob dir

for file in glob.glob('S:/1683428/Learning/TCS Training/Python Training/TryGlob/*'):
    print(file)
# Out:
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder1
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2

# %%
#Tried without passing recursive parameter

for file in glob.glob('S:/1683428/Learning/TCS Training/Python Training/TryGlob/**/*'):
    print(file)
# Out:
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder1\file_1.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder1\FromFolder1
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\file_3.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\FromFolder2
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\without_txt_ext.difflog

# %%
#Tried with recursive parameter as TRUE
#It will list all the folder and file from it's all subdirectories

for file in glob.glob('S:/1683428/Learning/TCS Training/Python Training/TryGlob/**/*', recursive = True):
    print(file)
# Out:
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder1
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder1\file_1.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder1\FromFolder1
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder1\FromFolder1\file_2.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\file_3.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\FromFolder2
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\without_txt_ext.difflog
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\FromFolder2\file_4.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\FromFolder2\UnknownFolder
# ...

# %%
#Passing /**/ only 
#It prints all the folders only from it's all subdirectories

for file in glob.glob('S:/1683428/Learning/TCS Training/Python Training/TryGlob/**/', recursive = True):
    print(file)
# Out:
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder1\
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder1\FromFolder1\
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\FromFolder2\
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\FromFolder2\UnknownFolder\

# %%
#Printing only files
#To print files only we need to pass sepcific pattern
#printing only .txt files

for file in glob.glob('S:/1683428/Learning/TCS Training/Python Training/TryGlob/**/*.txt', recursive = True):
    print(file)
# Out:
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder1\file_1.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder1\FromFolder1\file_2.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\file_3.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\FromFolder2\file_4.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\FromFolder2\UnknownFolder\unknown_file_5.txt

# %%
#Printing only files
#To print files only we need to pass sepcific pattern
#printing all files

for file in glob.glob('S:/1683428/Learning/TCS Training/Python Training/TryGlob/**/*.*', recursive = True):
    print(file)
# Out:
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder1\file_1.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder1\FromFolder1\file_2.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\file_3.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\without_txt_ext.difflog
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\FromFolder2\file_4.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\FromFolder2\UnknownFolder\unknown_file_5.txt

# %%
#Printing only files
#printing all files who's name starts with 'file'

for file in glob.glob('S:/1683428/Learning/TCS Training/Python Training/TryGlob/**/file_*.*', recursive = True):
    print(file)
# Out:
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder1\file_1.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder1\FromFolder1\file_2.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\file_3.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\FromFolder2\file_4.txt

# %%
#Printing only files
#printing all files containing 'file' word in it's name

for file in glob.glob('S:/1683428/Learning/TCS Training/Python Training/TryGlob/**/*file_*.*', recursive = True):
    print(file)
# Out:
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder1\file_1.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder1\FromFolder1\file_2.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\file_3.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\FromFolder2\file_4.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\FromFolder2\UnknownFolder\unknown_file_5.txt

# %%
#matching exact single character in file name
#Correct patter and file exists

for file in glob.glob('S:/1683428/Learning/TCS Training/Python Training/TryGlob/**/file_?.*', recursive = True):
    print(file)
# Out:
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder1\file_1.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder1\FromFolder1\file_2.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\file_3.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\FromFolder2\file_4.txt

# %%
#matching exact single character in file name
#If Given patter is wrong/ no such file exists

for file in glob.glob('S:/1683428/Learning/TCS Training/Python Training/TryGlob/**/file?.*', recursive = True):
    print(file)

# %%
#Match file contain any number in it's name
#AlphaNumerical name of file

for file in glob.glob('S:/1683428/Learning/TCS Training/Python Training/TryGlob/**/*[0-9].*', recursive = True):
    print(file)
# Out:
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder1\file_1.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder1\FromFolder1\file_2.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\file_3.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\FromFolder2\file_4.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\FromFolder2\UnknownFolder\unknown_file_5.txt

# %%
#Tried with recursive parameter as FALSE
#It will list all the folder and file from current directory only not from sub directory

for file in glob.glob('S:/1683428/Learning/TCS Training/Python Training/TryGlob/**/*', recursive = False):
    print(file)
# Out:
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder1\file_1.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder1\FromFolder1
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\file_3.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\FromFolder2
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\without_txt_ext.difflog

# %%
#Printing all the files who's name does not start with 'file' word
#Using ! operator
for file in glob.glob('S:/1683428/Learning/TCS Training/Python Training/TryGlob/**/[!file]*.*', recursive = True):
    print(file)
# Out:
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\without_txt_ext.difflog
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\FromFolder2\UnknownFolder\unknown_file_5.txt

# %%
#printing all the files who's name doesn't contain any number in it's name

for file in glob.glob('S:/1683428/Learning/TCS Training/Python Training/TryGlob/**/*[!0-9].*', recursive = True):
    print(file)
# Out:
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\without_txt_ext.difflog

# %%
#printing all the files who's name doesn't contain 1 in it's name

for file in glob.glob('S:/1683428/Learning/TCS Training/Python Training/TryGlob/**/*[!1].*', recursive = True):
    print(file)
# Out:
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder1\FromFolder1\file_2.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\file_3.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\without_txt_ext.difflog
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\FromFolder2\file_4.txt
# S:/1683428/Learning/TCS Training/Python Training/TryGlob\TryGlobFolder2\FromFolder2\UnknownFolder\unknown_file_5.txt
