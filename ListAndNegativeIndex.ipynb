# %%
test_list = [5, 7, 8, 2, 3, 5, 1]
print("The original list is : " + str(test_list))
# Out:
# The original list is : [5, 7, 8, 2, 3, 5, 1]

# %%
K = 5
print(len(test_list))
print(test_list.index(K))
# getting length using len() and subtracting index from it
res = test_list.index(K) -  len(test_list)
 
# printing result
print("The required Negative index : -" + str(res))
# Out:
# 7
# 0
# The required Negative index : --7

# %%
print(~test_list[::-1].index(K))
# Out:
# -2

# %%
print(test_list)
# Out:
# [5, 7, 8, 2, 3, 5, 1]

# %%
print(test_list[::-1])
# Out:
# [1, 5, 3, 2, 8, 7, 5]

# %%
print(test_list[len(test_list)-1:3:-1])
# Out:
# [1, 5, 3]

# %%
print(~test_list[6::-1].index(5))
# Out:
# -2

# %%
print(test_list)
# Out:
# [5, 7, 8, 2, 3, 5, 1]

# %%
print(test_list[1:-6:-1])
# Out:
# []

# %%
print(test_list[-2:4:-1])
# Out:
# [5]

# %%
i =0
print(len(test_list)//2)
# Out:
# 3

# %%
i=0
while i <= len(test_list)//2:
    print(test_list[i], end=" ")
    print(test_list[-(i+1)], end =" ")
    i += 1
# Out:
# 5 1 7 5 8 3 2 2

# %%
tmp = str("abba")
print(tmp)
# Out:
# abba

# %%
print(tmp == tmp[::-1])
# Out:
# True

# %%
num = 121
str1 = str(num)
print(num == int(str1[::-1]))
# Out:
# True
